# %% [markdown]
# <div class="frontmatter text-center">
# <h1>Geospatial Data Science</h1>
# <h2>Exercise 2: Geospatial Data in Python</h2>
# <h3>IT University of Copenhagen, Spring 2024</h3>
# <h3>Instructor: Ditte Stavski</h3>
# </div>
#
# This notebook was adapted from:
# * Automating GIS-Processes: https://autogis-site.readthedocs.io/en/latest/lessons/L2/exercise-2.html

# %% [markdown]
# ## Problem 1: Create Polygon from lists of coordinates
#
# In the first problem **the aim is to create a polygon based on the provided coordinates, and to plot the polygon on as a map.**
#
# Two lists: `longitudes` and `latitudes` contain the input coordinates for the polygon. The first coordinate pair looks like this: `(29.99671173095703, 63.748023986816406)`.
#
# The codeblocks below help you get started with the task. More detailed instructions are given below.

# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import pandas as pd
# Longitudes in decimal degrees
longitudes = [29.99671173095703, 31.58196258544922, 27.738052368164062, 26.50013542175293, 26.652359008789062, 25.921663284301758, 22.90027618408203, 23.257217407226562,
           23.335693359375, 22.87444305419922, 23.08465003967285, 22.565473556518555, 21.452774047851562, 21.66388702392578, 21.065969467163086, 21.67659568786621,
           21.496871948242188, 22.339998245239258, 22.288192749023438, 24.539581298828125, 25.444232940673828, 25.303749084472656, 24.669166564941406, 24.689163208007812,
           24.174999237060547, 23.68471908569336, 24.000761032104492, 23.57332992553711, 23.76513671875, 23.430830001831055, 23.6597900390625, 20.580928802490234, 21.320831298828125,
           22.398330688476562, 23.97638702392578, 24.934917449951172, 25.7611083984375, 25.95930290222168, 26.476804733276367, 27.91069221496582, 29.1027774810791, 29.29846954345703,
           28.4355525970459, 28.817358016967773, 28.459857940673828, 30.028610229492188, 29.075136184692383, 30.13492774963379, 29.818885803222656, 29.640830993652344, 30.57735824584961,
           29.99671173095703]

# Latitudes in decimal degrees
latitudes = [63.748023986816406, 62.90789794921875, 60.511383056640625, 60.44499588012695, 60.646385192871094, 60.243743896484375, 59.806800842285156, 59.91944122314453,
           60.02395248413086, 60.14555358886719, 60.3452033996582, 60.211936950683594, 60.56249237060547, 61.54027557373047, 62.59798049926758, 63.02013397216797,
           63.20353698730469, 63.27652359008789, 63.525691986083984, 64.79915618896484, 64.9533920288086, 65.51513671875, 65.65470886230469, 65.89610290527344, 65.79151916503906,
           66.26332092285156, 66.80228424072266, 67.1570053100586, 67.4168701171875, 67.47978210449219, 67.94589233398438, 69.060302734375, 69.32611083984375, 68.71110534667969,
           68.83248901367188, 68.580810546875, 68.98916625976562, 69.68568420410156, 69.9363784790039, 70.08860778808594, 69.70597076416016, 69.48533630371094, 68.90263366699219,
           68.84700012207031, 68.53485107421875, 67.69471740722656, 66.90360260009766, 65.70887756347656, 65.6533203125, 64.92096710205078, 64.22373962402344, 63.748023986816406]
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %% [markdown]
# **1. Create a Polygon variable `poly` based on the coordinates:**
# - Create a list of coordinate pairs based on the provided longitudes and latitudes and store the list in a variable `coordpairs`. A coordinate pair can be either a tuple or a list.
# - Create a shapely Polygon using the `coordpairs` -list. Store the polygon in a variable `poly`.
#
# Please use the provided variable names.

# %%
# Create a list of coordinate pairs
coordpairs = list(zip(longitudes, latitudes))

# Create a shapely Polygon using the 'coordpairs' -list
poly = Polygon(coordpairs)

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the first coordinate pair. Shoud be: (29.99671173095703, 63.748023986816406)
print(coordpairs[0])
# Out:
# (29.99671173095703, 63.748023986816406)

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the data type of your polygon:
print(poly.geom_type)
# Out:
# Polygon

# %% [markdown]
# **2. Insert the polygon into a GeoDataFrame called `geo`:**
# - Create an empty geodataframe variable `geo`
# - Insert our `poly` -polygon into the `geo` GeoDataFrame into a new column named 'geometry'
#
# Please use the provided variable names (replace `None` with your own code).

# %%
# Create an empty GeoDataFrame
geo = gpd.GeoDataFrame(geometry=[poly])

# %%
geo
# Out:
#                                             geometry
# 0  POLYGON ((29.99671 63.74802, 31.58196 62.90790...

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the number of rows:
assert len(geo) == 1

assert geo.geom_type.unique()[0] == 'Polygon'

# Check the content of the GeoDataFrame:
geo.head()
# Out:
#                                             geometry
# 0  POLYGON ((29.99671 63.74802, 31.58196 62.90790...

# %% [markdown]
# **3. Plot the polygon.**
#
# Note: you might need to call matplotlib pyplot `show()`-method in order to display the map

# %%
geo.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **4. Save the GeoDataFrame into a Geopackage called `'polygon.gpkg'`.**

# %%
# Save the GeoDataFrame into a new Shapefile called 'polygon.shp'.
fp = 'data/polygon.gpkg'

geo.to_file(fp)
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

#Check if output file exists
assert os.path.isfile(fp), "Output file does not exist."

# %% [markdown]
# # Problem 2: Points to map
#
# In this problem we continue to learn how to turn latitude and longitude coordinates into geometries.
#
# **Our aim is to plot a map based on a set of longitude and latitude coordinates that are stored in a csv file.**
# The coordinates are in WGS84 decimal degrees (EPSG:4326), and the data is stored in `some_posts.csv` comma separated file in the folder "data".
#
# First rows of the data look like this:
#
# ```
# lat,lon,timestamp,userid
# -24.980792492,31.484633302,2015-07-07 03:02,66487960
# -25.499224667,31.508905612,2015-07-07 03:18,65281761
# -24.342578456,30.930866066,2015-03-07 03:38,90916112
# -24.85461393,31.519718439,2015-10-07 05:04,37959089
# ```
#
# The data has 81379 rows and consists of locations and times of de-identified social media posts inside Kruger national park in South Africa:
#
# | Column | Description |
# |--------|-------------|
# | lat | y-coordinate of the post |
# | lon | x-coordinate of the post |
# | timestamp | Time when the post was uploaded |
# | userid | unique id for each user|
#
# *Note: Although the data is based on real social media data, the userids and timestamps have been randomized making it impossible to link the data to the original posts.*
#
# **First:**
#
# - Import the needed modules
# - Read the data from `data/some_posts.csv` into a Pandas dataframe called `data`
# - Create an empty column called `geometry` where you will store shapely Point objects
# - Insert Point objects into the column `geometry` based on the coordinate columns
#
# <details>
#   <summary>Hints</summary>
#
# You want to create a Shapely point *on each row*, based on columns `'lon'` and `'lat'`. You can achieve this by using one of these alternative approaches:
#
# - a `for`-loop and `iterrows()` to use the Point constructor on each row
# - the [apply method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) to apply the  Point constructor on each row.
# - a `for`-loop and a zipped object containing lon and lat (created using `zip`) and use the Point constructor on each lat, lon coordinate pair.
#
# </details>

# %%
import pandas as pd
from shapely.geometry import Point

# %%
data = pd.read_csv("data/some_posts.csv")

# %%
data["geometry"] = [Point(x,y) for x,y in list(zip(data.lat,data.lon))]
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
data
# Out:
#              lat        lon         timestamp    userid  \
# 0     -24.980792  31.484633  2015-07-07 03:02  66487960
# 1     -25.499225  31.508906  2015-07-07 03:18  65281761
# 2     -24.342578  30.930866  2015-03-07 03:38  90916112
# 3     -24.854614  31.519718  2015-10-07 05:04  37959089
# 4     -24.921069  31.520836  2015-10-07 05:19  27793716
# ...          ...        ...               ...       ...
# 81374 -24.799541  31.354469  2015-09-05 02:23  90744213
# 81375 -25.467992  30.956033  2015-02-05 02:40  71109799
# 81376 -25.332223  30.997409  2015-08-05 02:40  54796261
# 81377 -25.508851  31.005536  2015-08-05 02:43  78762204
# 81378 -25.498840  31.007430  2015-04-05 02:44  32190273
#
#                                  geometry
# 0      POINT (-24.980792492 31.484633302)
# 1      POINT (-25.499224667 31.508905612)
# 2      POINT (-24.342578456 30.930866066)
# 3       POINT (-24.85461393 31.519718439)
# 4      POINT (-24.921068894 31.520835558)
# ...                                   ...
# 81374   POINT (-24.79954083 31.354468659)
# 81375  POINT (-25.467991667 30.956033333)
# 81376  POINT (-25.332223289 30.997408647)
# 81377   POINT (-25.508851029 31.00553607)
# 81378          POINT (-25.49884 31.00743)
#
# [81379 rows x 5 columns]

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the result
assert len(data) == 81379

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the result
assert len(data.loc[data['geometry']== None]) == 0

# %% [markdown]
# **Next:**
# - Convert that DataFrame into a GeoDataFrame
#
# - Set the CRS as WGS84 (i.e. epsg code: 4326)
#
# - Save the data into a geopackage called `Kruger_posts.gpkg`

# %%
geo1 = gpd.GeoDataFrame(data,crs="epsg:4326")
geo.to_file("data/Kruger_posts.gpkg")
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check that the output file exists
import os
assert os.path.isfile(fp), "output geopackage does not exist"

assert len(geo) == 81379
assert geo.geom_type.unique()[0] == 'Point'
geo.head()
# Out:
#          lat        lon         timestamp    userid  \
# 0 -24.980792  31.484633  2015-07-07 03:02  66487960
# 1 -25.499225  31.508906  2015-07-07 03:18  65281761
# 2 -24.342578  30.930866  2015-03-07 03:38  90916112
# 3 -24.854614  31.519718  2015-10-07 05:04  37959089
# 4 -24.921069  31.520836  2015-10-07 05:19  27793716
#
#                      geometry
# 0  POINT (-24.98079 31.48463)
# 1  POINT (-25.49922 31.50891)
# 2  POINT (-24.34258 30.93087)
# 3  POINT (-24.85461 31.51972)
# 4  POINT (-24.92107 31.52084)

# %% [markdown]
# **Finally:**
# - Create a simple map of the points using the `plot()`-funtion.

# %%
geo["geometry"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Problem 3: How long have individuals travelled?
#
# In this problem the aim is to calculate the **distance** in meters that the individuals have travelled according to the social media posts (Euclidean distances between points). In this problem, we will need the `userid`-column and the points created in the previous problem. You will need the geopackage `Kruger_posts.gpkg` generated in Problem 2 as input file.
#
# Our goal is to answer these questions based on the input data:
# - *What was the shortest distance travelled in meters?*
# - *What was the mean distance travelled in meters?*
# - *What was the maximum distance travelled in meters?*
#
# Start with importing the required modules and loading the saved data.

# %%
from shapely.geometry import LineString

# %%
data = gpd.read_file("data/Kruger_posts.gpkg")

# %%
data.head()
# Out:
#          lat        lon         timestamp    userid  \
# 0 -24.980792  31.484633  2015-07-07 03:02  66487960
# 1 -25.499225  31.508906  2015-07-07 03:18  65281761
# 2 -24.342578  30.930866  2015-03-07 03:38  90916112
# 3 -24.854614  31.519718  2015-10-07 05:04  37959089
# 4 -24.921069  31.520836  2015-10-07 05:19  27793716
#
#                             geometry
# 0  POINT (-4695752.719 14973674.275)
# 1  POINT (-4748939.258 15014098.837)
# 2  POINT (-4672729.591 14859391.193)
# 3  POINT (-4679391.656 14969037.444)
# 4  POINT (-4686373.982 14973910.589)

# %% [markdown]
# 1. **Check the CRS of the input data. If this information is missing, set it as EPSG:4326 (WGS84).**
# 2. **Reproject the data from WGS84-projection into *EPSG:32735*-projection which stands for UTM Zone 35S (UTM zone for South Africa), in order to transform the data into the metric system (don't create a new variable, but update the existing variable `data`)**

# %%
data = data.to_crs("epsg:32735")

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the data
assert data.crs.to_epsg() == 32735

# %% [markdown]
# 3. **Group the data by userid**

# %%
grouped = data.sort_values("timestamp").groupby("userid")

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

#Check the number of groups:
assert len(grouped.groups) == data["userid"].nunique(), "Number of groups should match number of unique users!"

# %% [markdown]
# **4. Create LineString objects for each user connecting the points from oldest to latest:**
#
# <details>
#   <summary>Hints</summary>
#
#   **One possible method:**
#   - Create an empty DataFrame called `movements`.
#   - Create an empty column "geometry"
#   - Use a for-loop where you iterate over the grouped object. For each user's data:
#       - [sort](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html) the rows by timestamp
#       - create a LineString object based on the user's points
#       - Add the LineString to the geometry column of the `movements` dataframe. You can also add the `userid` in a separate column (or use the userid as index).
#   - Convert `movements` into a `GeoDataFrame` (you can replace the DataFrame created in the previous steps with the GeoDataFrame). Remember to set the `geometry` column.
#   - Set the CRS of the `movements` GeoDataFrame as `EPSG:32735`
#
#   OBS! Think about what happens if a visitor only has one entry/location?
#
# </details>

# %%
movements = pd.DataFrame()
movements["geometry"] = None

# %%
movements = grouped.geometry.apply(lambda x: LineString(x.values) if len(x.values) > 1 else x.values[0])

# %%
movements
# Out:
# userid
# 16301       LINESTRING (-4681550.088 14943799.279, -468323...
# 26589                       POINT (-4792681.729 14948384.789)
# 29322                       POINT (-4729750.563 15040717.257)
# 42181                       POINT (-4764400.982 14946675.913)
# 45136       LINESTRING (-4770692.230 14940874.449, -477069...
#                                   ...
# 99966397                    POINT (-4612489.515 14858007.342)
# 99986933    LINESTRING (-4638612.172 14901687.488, -463575...
# 99988918                    POINT (-4731181.206 14932198.635)
# 99990870    LINESTRING (-4788544.778 14942186.180, -478854...
# 99995791                    POINT (-4798919.320 14935848.605)
# Name: geometry, Length: 14990, dtype: geometry

# %%
a = [(-24.759508333, 31.3712), (-24.749845, 31.338316667), (-24.995803333, 31.592), (-24.791483333, 31.865171667), (-24.76017, 31.33943), (-25.102336167, 31.894695), (-24.774158333, 31.380341667), (-24.985141667, 31.625661667), (-25.122811167, 31.911866667)]
movements.at[1,"geometry"] = list(a)

# %%
for i in grouped:
    
    row = 0
    tmp = list(zip(i[1]["lat"], i[1]["lon"]))
    userid = i[1]["userid"].iloc[0]
    
    if len(tmp) < 1:
        print("shit < 1 lol")
    elif len(tmp) == 1:
        movements.at[row,"userid"] = userid
        movements.at[row,"geometry"] = list(tmp)
        row +=1
    elif len(tmp) > 1:
        movements.at[row,"geometry"] = list(tmp)
        movements.at[row,"userid"] = userid
        row += 1

# %%
movements
# Out:
#                           geometry      userid
# 0  [(-25.479763129, 30.894174496)]  99995791.0
# 1                              NaN         NaN
# 2                              NaN         NaN

# %%
for i in grouped:
    print(i[1]["userid"],i[1]["timestamp"])
# Out:
# 30512    16301
# 30535    16301
# 30545    16301
# 30770    16301
# 38232    16301
# 38235    16301
# 38909    16301
# 38911    16301
# 38913    16301
# Name: userid, dtype: int64 30512    2015-06-08 04:34
# 30535    2015-02-08 06:18
# 30545    2015-09-08 06:58
# 30770    2015-02-09 08:09
# 38232    2015-05-13 10:51
# 38235    2015-03-13 10:59
# 38909    2015-08-16 14:27
# 38911    2015-09-16 14:30
# 38913    2015-11-16 14:31
# Name: timestamp, dtype: object
# 61781    26589
# Name: userid, dtype: int64 61781    2015-02-25 01:54
# Name: timestamp, dtype: object
# 78280    29322
# Name: userid, dtype: int64 78280    2015-02-28 10:25
# Name: timestamp, dtype: object
# 8081    42181
# Name: userid, dtype: int64 8081    2015-08-08 13:18
# Name: timestamp, dtype: object
# 80613    45136
# 81278    45136
# Name: userid, dtype: int64 80613    2015-11-03 07:36
# 81278    2015-04-04 15:46
# Name: timestamp, dtype: object
# 71512    48971
# Name: userid, dtype: int64 71512    2015-06-07 17:18
# Name: timestamp, dtype: object
# 42402    50136
# 42439    50136
# 42453    50136
# 42478    50136
# 42526    50136
# 42566    50136
# 42620    50136
# 42670    50136
# 42751    50136
# 42880    50136
# Name: userid, dtype: int64 42402    2015-09-03 14:20
# 42439    2015-08-03 16:40
# 42453    2015-05-03 17:32
# 42478    2015-09-04 02:15
# 42526    2015-10-04 07:08
# 42566    2015-06-04 10:26
# 42620    2015-08-04 14:48
# 42670    2015-01-04 17:32
# 42751    2015-11-05 08:05
# 42880    2015-03-05 17:07
# Name: timestamp, dtype: object
# 79157    50530
# Name: userid, dtype: int64 79157    2015-09-30 18:45
# Name: timestamp, dtype: object
# 60285    66129
# Name: userid, dtype: int64 60285    2015-08-18 04:01
# Name: timestamp, dtype: object
# 4003    74329
# Name: userid, dtype: int64 4003    2015-10-21 10:18
# Name: timestamp, dtype: object
# 60235    75914
# Name: userid, dtype: int64 60235    2015-08-17 16:20
# Name: timestamp, dtype: object
# 2388    76069
# Name: userid, dtype: int64 2388    2015-09-06 07:11
# Name: timestamp, dtype: object
# 15288    88775
# 15289    88775
# Name: userid, dtype: int64 15288    2015-02-07 16:19
# 15289    2015-08-07 16:34
# Name: timestamp, dtype: object
# 37496    88918
# 37879    88918
# Name: userid, dtype: int64 37496    2015-01-10 04:12
# 37879    2015-01-11 15:48
# Name: timestamp, dtype: object
# 74848    90156
# 74852    90156
# 75080    90156
# 75081    90156
# 75083    90156
# 75085    90156
# 75089    90156
# 75091    90156
# Name: userid, dtype: int64 74848    2015-04-20 07:22
# 74852    2015-11-20 07:31
# 75080    2015-05-20 16:17
# 75081    2015-12-20 16:20
# 75083    2015-02-20 16:23
# 75085    2015-07-20 16:26
# 75089    2015-11-20 16:28
# 75091    2015-06-20 16:30
# Name: timestamp, dtype: object
# 81361    120615
# Name: userid, dtype: int64 81361    2015-11-04 20:38
# Name: timestamp, dtype: object
# 66934    133296
# Name: userid, dtype: int64 66934    2015-07-18 11:34
# Name: timestamp, dtype: object
# 47421    141256
# Name: userid, dtype: int64 47421    2015-10-24 14:24
# Name: timestamp, dtype: object
# 4775    156058
# Name: userid, dtype: int64 4775    2015-11-25 06:41
# Name: timestamp, dtype: object
# 59189    161653
# Name: userid, dtype: int64 59189    2015-08-12 18:00
# Name: timestamp, dtype: object
# 35734    174181
# 35735    174181
# Name: userid, dtype: int64 35734    2015-04-02 15:25
# 35735    2015-01-02 15:26
# Name: timestamp, dtype: object
# 47034    177106
# Name: userid, dtype: int64 47034    2015-04-23 06:58
# Name: timestamp, dtype: object
# 7616    177600
# 9609    177600
# 9610    177600
# 9611    177600
# 9678    177600
# 9679    177600
# Name: userid, dtype: int64 7616    2015-02-05 17:51
# 9609    2015-07-18 13:11
# 9610    2015-08-18 13:22
# 9611    2015-07-18 13:24
# 9678    2015-09-19 00:30
# 9679    2015-04-19 00:40
# Name: timestamp, dtype: object
# 70740    180146
# Name: userid, dtype: int64 70740    2015-06-05 10:08
# Name: timestamp, dtype: object
# 52587    181216
# 52688    181216
# 52779    181216
# 52838    181216
# 52965    181216
# Name: userid, dtype: int64 52587    2015-12-14 16:59
# 52688    2015-03-15 11:25
# 52779    2015-03-15 17:47
# 52838    2015-10-16 07:51
# 52965    2015-01-16 18:19
# Name: timestamp, dtype: object
# 4006     184404
# 4203     184404
# 4974     184404
# 74796    184404
# 76816    184404
# Name: userid, dtype: int64 4006     2015-08-21 10:31
# 4203     2015-05-22 08:25
# 4974     2015-07-25 18:30
# 74796    2015-04-20 04:45
# 76816    2015-07-25 09:13
# Name: timestamp, dtype: object
# 47691    186335
# Name: userid, dtype: int64 47691    2015-08-25 17:04
# Name: timestamp, dtype: object
# 78179    193414
# 78912    193414
# 79513    193414
# Name: userid, dtype: int64 78179    2015-12-28 07:28
# 78912    2015-12-30 05:31
# 79513    2015-03-31 16:39
# Name: timestamp, dtype: object
# 56739    195149
# 56771    195149
# 56775    195149
# 56777    195149
# 56779    195149
# Name: userid, dtype: int64 56739    2015-04-04 04:35
# 56771    2015-12-04 07:05
# 56775    2015-04-04 07:12
# 56777    2015-05-04 07:14
# 56779    2015-02-04 07:17
# Name: timestamp, dtype: object
# 51067    198845
# 51726    198845
# Name: userid, dtype: int64 51067    2015-12-08 15:39
# 51726    2015-08-11 06:49
# Name: timestamp, dtype: object
# 75654    209862
# Name: userid, dtype: int64 75654    2015-08-22 05:14
# Name: timestamp, dtype: object
# 10933    214933
# 10935    214933
# Name: userid, dtype: int64 10933    2015-10-30 10:17
# 10935    2015-12-30 10:23
# Name: timestamp, dtype: object
# 72658    217091
# 73097    217091
# 73099    217091
# Name: userid, dtype: int64 72658    2015-12-12 17:56
# 73097    2015-04-14 04:56
# 73099    2015-01-14 04:58
# Name: timestamp, dtype: object
# 36677    222264
# 48629    222264
# 48631    222264
# Name: userid, dtype: int64 36677    2015-09-06 09:39
# 48629    2015-04-30 01:42
# 48631    2015-03-30 01:47
# Name: timestamp, dtype: object
# 16713    228231
# Name: userid, dtype: int64 16713    2015-07-19 08:08
# Name: timestamp, dtype: object
# 13437    231302
# Name: userid, dtype: int64 13437    2015-04-21 09:43
# Name: timestamp, dtype: object
# 3610    232626
# 3611    232626
# 3612    232626
# 3613    232626
# 3614    232626
#          ...
# 4111    232626
# 4112    232626
# 4113    232626
# 4114    232626
# 4115    232626
# Name: userid, Length: 91, dtype: int64 3610    2015-02-18 17:44
# 3611    2015-10-18 17:45
# 3612    2015-05-18 17:46
# 3613    2015-09-18 17:47
# 3614    2015-12-18 17:48
#               ...
# 4111    2015-07-21 16:56
# 4112    2015-11-21 16:57
# 4113    2015-12-21 16:57
# 4114    2015-08-21 16:58
# 4115    2015-08-21 16:59
# Name: timestamp, Length: 91, dtype: object
# 615    234249
# Name: userid, dtype: int64 615    2015-11-13 17:40
# Name: timestamp, dtype: object
# 1036    252731
# 1108    252731
# 1182    252731
# 1183    252731
# 1189    252731
# Name: userid, dtype: int64 1036    2015-04-18 06:43
# 1108    2015-05-19 05:44
# 1182    2015-06-20 06:16
# 1183    2015-10-20 06:21
# 1189    2015-12-20 07:28
# Name: timestamp, dtype: object
# 40287    258001
# Name: userid, dtype: int64 40287    2015-11-24 03:41
# Name: timestamp, dtype: object
# 3494    270112
# Name: userid, dtype: int64 3494    2015-09-17 16:54
# Name: timestamp, dtype: object
# 49525    272102
# 49612    272102
# 50849    272102
# Name: userid, dtype: int64 49525    2015-04-02 15:58
# 49612    2015-05-03 06:15
# 50849    2015-07-07 18:12
# Name: timestamp, dtype: object
# 47890    273288
# 49272    273288
# Name: userid, dtype: int64 47890    2015-04-26 14:51
# 49272    2015-06-01 13:27
# Name: timestamp, dtype: object
# 14202    275948
# Name: userid, dtype: int64 14202    2015-06-27 06:07
# Name: timestamp, dtype: object
# 59081    280667
# 59201    280667
# 61778    280667
# 64472    280667
# Name: userid, dtype: int64 59081    2015-09-12 12:55
# 59201    2015-08-13 22:31
# 61778    2015-09-24 20:03
# 64472    2015-07-07 22:48
# Name: timestamp, dtype: object
# 37384    293435
# Name: userid, dtype: int64 37384    2015-01-09 11:40
# Name: timestamp, dtype: object
# 37192    296658
# Name: userid, dtype: int64 37192    2015-01-08 14:09
# Name: timestamp, dtype: object
# 77684    314463
# Name: userid, dtype: int64 77684    2015-06-27 06:42
# Name: timestamp, dtype: object
# 7446     314489
# 7447     314489
# 7448     314489
# 7449     314489
# 7450     314489
# 7451     314489
# 21497    314489
# 21790    314489
# 21791    314489
# Name: userid, dtype: int64 7446     2015-04-05 03:52
# 7447     2015-09-05 03:52
# 7448     2015-08-05 03:52
# 7449     2015-11-05 03:53
# 7450     2015-06-05 03:53
# 7451     2015-11-05 03:53
# 21497    2015-09-19 08:30
# 21790    2015-01-20 10:32
# 21791    2015-11-20 10:34
# Name: timestamp, dtype: object
# 29080    330988
# 29361    330988
# 44792    330988
# 80290    2015-03-02 14:05
# Name: timestamp, dtype: object
# 9001    390194
# Name: userid, dtype: int64 9001    2015-05-13 13:25
# Name: timestamp, dtype: object
# 21254    390297
# 21735    390297
# Name: userid, dtype: int64 21254    2015-09-18 11:06
# 21735    2015-04-20 06:42
# Name: timestamp, dtype: object
# 74471    396277
# Name: userid, dtype: int64 74471    2015-09-18 17:48
# Name: timestamp, dtype: object
# 16938    406869
# 17055    406869
# 17057    406869
# 17058    406869
# 17749    406869
# Name: userid, dtype: int64 16938    2015-12-21 12:23
# 17055    2015-12-22 03:00
# 17057    2015-08-22 03:10
# 17058    2015-03-22 03:15
# 17749    2015-08-26 12:30
# Name: timestamp, dtype: object
# 39042    411014
# Name: userid, dtype: int64 39042    2015-03-17 09:50
# Name: timestamp, dtype: object
# 59433    411165
# Name: userid, dtype: int64 59433    2015-03-13 15:55
# Name: timestamp, dtype: object
# 53895    432164
# Name: userid, dtype: int64 53895    2015-03-21 16:02
# Name: timestamp, dtype: object
# 73870    432977
# 73871    432977
# Name: userid, dtype: int64 73870    2015-08-16 14:29
# 73871    2015-11-16 14:33
# Name: timestamp, dtype: object
# 12146    438452
# Name: userid, dtype: int64 12146    2015-10-09 19:05
# Name: timestamp, dtype: object
# 71781    439056
# Name: userid, dtype: int64 71781    2015-03-09 03:35
# Name: timestamp, dtype: object
# 2875    444245
# Name: userid, dtype: int64 2875    2015-11-12 09:45
# Name: timestamp, dtype: object
# 31070    458007
# 33434    458007
# 34085    458007
# 34128    458007
# 34497    458007
# 38835    458007
# 42649    458007
# 46768    458007
# 47613    458007
# 47741    458007
# 47742    458007
# 49275    458007
# 49286    458007
# 50349    458007
# 51917    458007
# 54743    458007
# 56559    458007
# 56560    458007
# 58612    458007
# 58765    458007
# 59667    458007
# 60735    458007
# 61710    458007
# 62860    458007
# 63110    458007
# 64270    458007
# 64530    458007
# 64746    458007
# 64966    458007
# 65227    458007
# 65569    458007
# 66314    458007
# 67062    458007
# 80403    458007
# 80407    458007
# 80836    458007
# 81265    458007
# Name: userid, dtype: int64 31070    2015-08-11 03:44
# 33434    2015-12-22 07:32
# 34085    2015-09-25 12:48
# 34128    2015-07-25 15:43
# 34497    2015-11-27 14:35
# 38835    2015-12-16 09:07
# 42649    2015-12-04 16:21
# 46768    2015-06-21 18:30
# 47613    2015-09-25 12:06
# 47741    2015-12-26 03:48
# 47742    2015-12-26 03:48
# 49275    2015-06-01 13:35
# 49286    2015-01-01 14:34
# 50349    2015-06-06 06:39
# 51917    2015-03-11 17:05
# 54743    2015-10-25 12:13
# 56559    2015-03-02 19:31
# 56560    2015-02-02 19:33
# 58612    2015-02-11 04:13
# 58765    2015-06-11 12:56
# 59667    2015-08-14 15:07
# 60735    2015-05-19 11:26
# 61710    2015-06-24 14:26
# 62860    2015-11-30 14:43
# 63110    2015-11-31 15:00
# 64270    2015-03-06 03:00
# 64530    2015-10-07 07:13
# 64746    2015-10-08 08:52
# 64966    2015-04-08 19:33
# 65227    2015-05-09 17:10
# 65569    2015-12-11 15:10
# 66314    2015-09-15 09:02
# 67062    2015-01-19 07:18
# 80403    2015-12-02 17:33
# 80407    2015-04-02 17:36
# 80836    2015-01-03 15:56
# 81265    2015-05-04 15:17
# Name: timestamp, dtype: object
# 60458    460469
# Name: userid, dtype: int64 60458    2015-09-18 12:36
# Name: timestamp, dtype: object
# 3386    486108
# Name: userid, dtype: int64 3386    2015-08-16 18:38
# Name: timestamp, dtype: object
# 61986    494401
# Name: userid, dtype: int64 61986    2015-07-25 16:24
# Name: timestamp, dtype: object
# 45688    506438
# 46343    506438
# Name: userid, dtype: int64 45688    2015-06-17 13:58
# 46343    2015-06-20 08:30
# Name: timestamp, dtype: object
# 61176    507547
# 65761    507547
# Name: userid, dtype: int64 61176    2015-08-21 16:53
# 65761    2015-01-12 15:32
# Name: timestamp, dtype: object
# 18162    520855
# 18189    520855
# 18394    520855
# 18625    520855
# Name: userid, dtype: int64 18162    2015-09-29 09:56
# 18189    2015-02-29 12:23
# 18394    2015-03-30 13:38
# 18625    2015-04-31 17:42
# Name: timestamp, dtype: object
# 23621    526570
# 23622    526570
# 23624    526570
# Name: userid, dtype: int64 23621    2015-08-29 14:41
# 23622    2015-09-29 14:42
# 23624    2015-11-29 14:43
# Name: timestamp, dtype: object
# 105     527064
# 184     527064
# 253     527064
# 6868    527064
# 6892    527064
# 6979    527064
# 7000    527064
# Name: userid, dtype: int64 105     2015-04-08 12:29
# 184     2015-09-09 10:36
# 253     2015-02-09 17:20
# 6868    2015-03-02 13:05
# 6892    2015-10-02 15:04
# 6979    2015-04-03 04:57
# 7000    2015-04-03 06:35
# Name: timestamp, dtype: object
# 74066    533258
# Name: userid, dtype: int64 74066    2015-09-17 09:05
# Name: timestamp, dtype: object
# 9924    537021
# Name: userid, dtype: int64 9924    2015-06-21 03:19
# Name: timestamp, dtype: object
# 9776     552457
# 10063    552457
# 10064    552457
# 10065    552457
# 10066    552457
# Name: userid, dtype: int64 9776     2015-10-19 13:55
# 10063    2015-08-22 08:21
# 10064    2015-05-22 08:22
# 10065    2015-01-22 08:23
# 10066    2015-11-22 08:24
# Name: timestamp, dtype: object
# 46924    556169
# 46928    556169
# 46929    556169
# 47110    556169
# 47196    556169
# 47199    556169
# Name: userid, dtype: int64 46924    2015-10-22 13:36
# 46928    2015-08-22 13:39
# 46929    2015-08-22 13:40
# 47110    2015-07-23 11:03
# 47196    2015-01-23 16:33
# 47199    2015-04-23 16:44
# Name: timestamp, dtype: object
# 47473    563046
# Name: userid, dtype: int64 47473    2015-01-24 18:08
# Name: timestamp, dtype: object
# 6529    563084
# 6643    563084
# Name: userid, dtype: int64 6529    2015-04-01 09:32
# 6643    2015-04-01 15:50
# Name: timestamp, dtype: object
# 76062    568413
# Name: userid, dtype: int64 76062    2015-09-23 11:42
# Name: timestamp, dtype: object
# 77820    574591
# Name: userid, dtype: int64 77820    2015-03-27 11:57
# Name: timestamp, dtype: object
# 33226    584619
# 33228    584619
# Name: userid, dtype: int64 33226    2015-06-21 10:06
# 33228    2015-07-21 10:10
# Name: timestamp, dtype: object
# 51079    585133
# 55717    585133
# 67419    585133
# Name: userid, dtype: int64 51079    2015-07-08 16:42
# 55717    2015-04-29 13:38
# 67419    2015-01-21 05:19
# Name: timestamp, dtype: object
# 44163    588121
# 44220    588121
# 44783    588121
# Name: userid, dtype: int64 44163    2015-10-11 08:45
# 44220    2015-08-11 13:47
# 44783    2015-03-14 03:04
# Name: timestamp, dtype: object
# 79735    599597
# Name: userid, dtype: int64 79735    2015-09-01 07:37
# Name: timestamp, dtype: object
# 79389    609755
# Name: userid, dtype: int64 79389    2015-04-31 11:49
# Name: timestamp, dtype: object
# 45303    614781
# Name: userid, dtype: int64 45303    2015-12-16 06:25
# Name: timestamp, dtype: object
# 79738    615986
# Name: userid, dtype: int64 79738    2015-04-01 07:43
# Name: timestamp, dtype: object
# 10822    622686
# Name: userid, dtype: int64 10822    2015-02-29 05:42
# Name: timestamp, dtype: object
# 43647    632460
# 44151    632460
# 44289    632460
# 44341    632460
# Name: userid, dtype: int64 43647    2015-05-09 07:04
# 44151    2015-03-11 07:45
# 44289    2015-06-11 18:10
# 44341    2015-04-12 05:39
# Name: timestamp, dtype: object
# 7309    633782
# Name: userid, dtype: int64 7309    2015-07-04 11:21
# Name: timestamp, dtype: object
# 64790    651795
# 64847    651795
# 64853    651795
# 64854    651795
# 64857    651795
# 64858    651795
# 64860    651795
# 64862    651795
# 64863    651795
# 64866    651795
# 64867    651795
# 64868    651795
# Name: userid, dtype: int64 64790    2015-01-08 11:24
# 64847    2015-04-08 14:33
# 64853    2015-01-08 15:16
# 64854    2015-02-08 15:17
# 64857    2015-06-08 15:18
# 64858    2015-12-08 15:18
# 64860    2015-08-08 15:20
# 64862    2015-02-08 15:20
# 64863    2015-06-08 15:21
# 64866    2015-10-08 15:22
# 64867    2015-09-08 15:23
# 64868    2015-09-08 15:24
# Name: timestamp, dtype: object
# 47441    655300
# 47442    655300
# 47444    655300
# 47445    655300
# 47579    655300
# 48535    655300
# Name: userid, dtype: int64 47441    2015-02-24 15:09
# 47442    2015-12-24 15:13
# 47444    2015-06-24 15:14
# 47445    2015-10-24 15:16
# 47579    2015-11-25 10:10
# 48535    2015-02-29 13:03
# Name: timestamp, dtype: object
# 44116    672501
# 52638    672501
# 52640    672501
# 52641    672501
# Name: userid, dtype: int64 44116    2015-11-11 04:37
# 52638    2015-12-15 05:37
# 52640    2015-08-15 05:39
# 52641    2015-01-15 05:41
# Name: timestamp, dtype: object
# 36430    676709
# Name: userid, dtype: int64 36430    2015-09-05 10:36
# Name: timestamp, dtype: object
# 5651    677171
# Name: userid, dtype: int64 5651    2015-10-28 10:52
# Name: timestamp, dtype: object
# 43592    678660
# 43593    678660
# 43596    678660
# 43599    678660
# 43848    678660
# 43849    678660
# 43850    678660
# 43851    678660
# 43852    678660
# 43853    678660
# 44745    678660
# Name: userid, dtype: int64 43592    2015-08-08 19:04
# 43593    2015-01-08 19:11
# 43596    2015-04-08 19:14
# 43599    2015-03-08 19:20
# 43848    2015-10-10 22:24
# 43849    2015-03-10 22:32
# 43850    2015-03-10 22:35
# 43851    2015-01-10 22:38
# 43852    2015-08-10 22:43
# 43853    2015-08-10 22:50
# 44745    2015-04-13 18:00
# Name: timestamp, dtype: object
# 46469    680332
# 52667    680332
# 59346    680332
# Name: userid, dtype: int64 46469    2015-04-20 16:51
# 52667    2015-02-15 08:51
# 59346    2015-06-13 12:06
# Name: timestamp, dtype: object
# 54300    687327
# 56356    687327
# 60700    687327
# 62446    687327
# 64495    687327
# Name: userid, dtype: int64 54300    2015-12-23 16:40
# 56356    2015-12-02 06:55
# 60700    2015-08-19 09:25
# 62446    2015-04-28 10:04
# 64495    2015-10-07 04:13
# Name: timestamp, dtype: object
# 3075    696213
# 3123    696213
# 3174    696213
# 3190    696213
# 3294    696213
# Name: userid, dtype: int64 3075    2015-10-14 09:07
# 3123    2015-10-14 14:57
# 3174    2015-12-15 03:32
# 3190    2015-03-15 06:58
# 3294    2015-11-16 05:50
# Name: timestamp, dtype: object
# 63577    696566
# Name: userid, dtype: int64 63577    2015-04-02 08:09
# Name: timestamp, dtype: object
# 2676     706132
# 2686     706132
# 2687     706132
# 6256     706132
# 6257     706132
# 6895     706132
# 79967    706132
# Name: userid, dtype: int64 2676     2015-01-09 12:25
# 2686     2015-01-09 15:41
# 2687     2015-03-09 15:43
# 6256     2015-08-31 07:30
# 6257     2015-10-31 07:31
# 6895     2015-04-02 15:13
# 79967    2015-04-01 16:25
# Name: timestamp, dtype: object
# 41349    706620
# 41350    706620
# 41351    706620
# 41352    706620
# 41354    706620
# 41356    706620
# Name: userid, dtype: int64 41349    2015-07-29 11:15
# 41350    2015-03-29 11:17
# 41351    2015-05-29 11:18
# 41352    2015-11-29 11:19
# 41354    2015-01-29 11:21
# 41356    2015-07-29 11:22
# Name: timestamp, dtype: object
# 53912    709049
# 54215    709049
# 54217    709049
# 54218    709049
# 54295    709049
# 54415    709049
# 54580    709049
# Name: userid, dtype: int64 53912    2015-05-21 17:55
# 54215    2015-12-23 09:55
# 54217    2015-01-23 10:07
# 54218    2015-12-23 10:09
# 54295    2015-04-23 16:24
# 54415    2015-11-24 10:01
# 54580    2015-01-24 17:53
# Name: timestamp, dtype: object
# 57607    710708
# 58209    710708
# 58210    710708
# 80001    710708
# Name: userid, dtype: int64 57607    2015-04-07 09:48
# 58209    2015-02-09 07:54
# 58210    2015-09-09 07:54
# 80001    2015-12-01 17:37
# Name: timestamp, dtype: object
# 22774    717693
# 28839    717693
# 30511    717693
# 30517    717693
# Name: userid, dtype: int64 22774    2015-05-25 16:24
# 28839    2015-07-29 09:27
# 30511    2015-11-08 04:16
# 30517    2015-03-08 05:03
# Name: timestamp, dtype: object
# 66197    720578
# 66204    720578
# 66388    720578
# Name: userid, dtype: int64 66197    2015-11-14 17:23
# 66204    2015-01-14 18:05
# 66388    2015-09-15 14:05
# Name: timestamp, dtype: object
# 17767    725740
# 17899    725740
# 18128    725740
# 18214    725740
# 21367    725740
# Name: userid, dtype: int64 17767    2015-04-26 13:55
# 17899    2015-03-27 16:06
# 18128    2015-12-29 08:33
# 18214    2015-11-29 14:09
# 21367    2015-04-18 16:42
# Name: timestamp, dtype: object
# 40828    729935
# 40983    729935
# Name: userid, dtype: int64 40828    2015-03-26 15:23
# 40983    2015-09-27 11:48
# Name: timestamp, dtype: object
# 7100    736633
# Name: userid, dtype: int64 7100    2015-08-03 13:07
# Name: timestamp, dtype: object
# 22834    747503
# Name: userid, dtype: int64 22834    2015-09-26 03:18
# Name: timestamp, dtype: object
# 67918    749378
# 68032    749378
# Name: userid, dtype: int64 67918    2015-01-23 06:48
# 68032    2015-09-23 12:47
# Name: timestamp, dtype: object
# 49203    780873
# Name: userid, dtype: int64 49203    2015-09-01 07:27
# Name: timestamp, dtype: object
# 14023    795469
# 14134    795469
# Name: userid, dtype: int64 14023    2015-06-25 14:35
# 14134    2015-05-26 14:04
# Name: timestamp, dtype: object
# 34247    801141
# 34963    801141
# 34965    801141
# Name: userid, dtype: int64 34247    2015-09-26 08:59
# 34963    2015-12-29 14:17
# 34965    2015-09-29 14:25
# Name: timestamp, dtype: object
# 18073    803774
# 18517    803774
# 18518    803774
# Name: userid, dtype: int64 18073    2015-04-29 03:38
# 18517    2015-05-31 08:33
# 18518    2015-03-31 08:33
# Name: timestamp, dtype: object
# 693      817930
# 1761     817930
# 13405    817930
# 28577    817930
# Name: userid, dtype: int64 693      2015-10-14 16:24
# 1761     2015-12-27 09:06
# 13405    2015-02-21 03:13
# 28577    2015-08-27 15:31
# Name: timestamp, dtype: object
# 53399    822042
# 53402    822042
# 53580    822042
# 53666    822042
# 53670    822042
# Name: userid, dtype: int64 53399    2015-07-19 07:12
# 53402    2015-07-19 07:26
# 53580    2015-05-20 08:09
# 53666    2015-12-20 12:26
# 53670    2015-03-20 12:44
# Name: timestamp, dtype: object
# 36471    831945
# 36472    831945
# 36473    831945
# 36588    831945
# 36651    831945
# 36816    831945
# 36951    831945
# 37407    831945
# 37427    831945
# 37520    831945
# 37819    831945
# 37835    831945
# 37851    831945
# 38295    831945
# 38296    831945
# 38486    831945
# 38488    831945
# 38877    831945
# Name: userid, dtype: int64 36471    2015-12-05 13:04
# 36472    2015-09-05 13:06
# 36473    2015-01-05 13:07
# 36588    2015-06-06 03:01
# 36651    2015-01-06 07:30
# 36816    2015-05-06 17:47
# 36951    2015-09-07 13:54
# 37407    2015-08-09 13:44
# 37427    2015-05-09 14:40
# 37520    2015-10-10 06:41
# 37819    2015-09-11 11:38
# 37835    2015-05-11 13:19
# 37851    2015-02-11 13:46
# 38295    2015-06-13 15:05
# 38296    2015-02-13 15:08
# 38486    2015-06-14 12:50
# 38488    2015-05-14 12:53
# 38877    2015-04-16 12:20
# Name: timestamp, dtype: object
# 79304    851500
# Name: userid, dtype: int64 79304    2015-06-31 07:57
# Name: timestamp, dtype: object
# 19940    854975
# Name: userid, dtype: int64 19940    2015-12-10 06:51
# Name: timestamp, dtype: object
# 40222    856626
# 40223    856626
# Name: userid, dtype: int64 40222    2015-05-23 14:40
# 40223    2015-03-23 14:48
# Name: timestamp, dtype: object
# 76011    868636
# Name: userid, dtype: int64 76011    2015-05-23 08:50
# Name: timestamp, dtype: object
# 40966    882546
# Name: userid, dtype: int64 40966    2015-09-27 10:36
# Name: timestamp, dtype: object
# 47264    889531
# 49007    889531
# Name: userid, dtype: int64 47264    2015-06-24 04:50
# 49007    2015-09-31 11:10
# Name: timestamp, dtype: object
# 46793    894508
# Name: userid, dtype: int64 46793    2015-09-22 02:30
# Name: timestamp, dtype: object
# 37363    903602
# 37402    903602
# 37550    903602
# 37667    903602
# 37793    903602
# 37827    903602
# 37852    903602
# 37886    903602
# 38039    903602
# 38213    903602
# 38293    903602
# 38410    903602
# 38532    903602
# 38832    903602
# 38847    903602
# 38965    903602
# 39152    903602
# Name: userid, dtype: int64 37363    2015-02-09 09:16
# 37402    2015-10-09 13:26
# 37550    2015-10-10 09:09
# 37667    2015-04-10 15:59
# 37793    2015-08-11 09:36
# 37827    2015-02-11 12:44
# 37852    2015-08-11 13:51
# 37886    2015-06-11 16:26
# 38039    2015-07-12 13:57
# 38213    2015-11-13 10:00
# 38293    2015-11-13 14:52
# 38410    2015-04-14 04:10
# 38532    2015-03-14 15:16
# 38832    2015-08-16 08:42
# 38847    2015-04-16 10:15
# 38965    2015-01-16 19:24
# 39152    2015-04-17 17:57
# Name: timestamp, dtype: object
# 14438    907022
# Name: userid, dtype: int64 14438    2015-04-01 04:57
# Name: timestamp, dtype: object
# 33628    907411
# Name: userid, dtype: int64 33628    2015-04-23 07:27
# Name: timestamp, dtype: object
# 45009    927701
# 45800    927701
# Name: userid, dtype: int64 45009    2015-12-14 18:12
# 45800    2015-12-18 04:43
# Name: timestamp, dtype: object
# 55218    928443
# Name: userid, dtype: int64 55218    2015-06-27 10:39
# Name: timestamp, dtype: object
# 59125    935230
# 59379    935230
# 59440    935230
# 59661    935230
# Name: userid, dtype: int64 59125    2015-12-12 14:34
# 59379    2015-04-13 13:32
# 59440    2015-04-13 16:23
# 59661    2015-04-14 14:57
# Name: timestamp, dtype: object
# 2436     935642
# 17295    935642
# 43749    935642
# Name: userid, dtype: int64 2436     2015-12-06 14:43
# 17295    2015-09-23 05:52
# 43749    2015-02-09 13:28
# Name: timestamp, dtype: object
# 34825    937965
# 34826    937965
# 35231    937965
# 35232    937965
# Name: userid, dtype: int64 34825    2015-08-29 05:55
# 34826    2015-12-29 06:02
# 35231    2015-07-30 16:39
# 35232    2015-09-30 16:40
# Name: timestamp, dtype: object
# 7831    944258
# Name: userid, dtype: int64 7831    2015-02-07 03:23
# Name: timestamp, dtype: object
# 41330    966216
# 41346    966216
# Name: userid, dtype: int64 41330    2015-08-29 10:12
# 41346    2015-04-29 11:01
# Name: timestamp, dtype: object
# 76212    970970
# Name: userid, dtype: int64 76212    2015-06-24 01:18
# Name: timestamp, dtype: object
# 6032     987622
# 6033     987622
# 53811    987622
# 53820    987622
# 53858    987622
# 53859    987622
# 53933    987622
# 53935    987622
# 54038    987622
# 54649    987622
# 54667    987622
# 54676    987622
# 54677    987622
# 54787    987622
# 54788    987622
# 54811    987622
# 55075    987622
# Name: userid, dtype: int64 6032     2015-11-30 02:09
# 6033     2015-11-30 02:13
# 53811    2015-03-21 09:55
# 53820    2015-12-21 10:38
# 53858    2015-02-21 13:44
# 54094    2015-11-22 19:36
# 54095    2015-04-22 19:41
# Name: timestamp, dtype: object
# 37213    1203555
# 37238    1203555
# 37639    1203555
# 37874    1203555
# 38284    1203555
# 38711    1203555
# Name: userid, dtype: int64 37213    2015-08-08 15:22
# 37238    2015-07-08 16:53
# 37639    2015-01-10 14:22
# 37874    2015-02-11 15:16
# 38284    2015-09-13 14:20
# 38711    2015-01-15 14:43
# Name: timestamp, dtype: object
# 52209    1213674
# 52757    1213674
# 53863    1213674
# Name: userid, dtype: int64 52209    2015-05-13 06:49
# 52757    2015-03-15 16:19
# 53863    2015-01-21 14:03
# Name: timestamp, dtype: object
# 8420    1215420
# 8422    1215420
# 8425    1215420
# Name: userid, dtype: int64 8420    2015-09-10 14:38
# 8422    2015-03-10 14:53
# 8425    2015-07-10 14:59
# Name: timestamp, dtype: object
# 64706    1230540
# Name: userid, dtype: int64 64706    2015-11-08 06:38
# Name: timestamp, dtype: object
# 14674    1234155
# 14675    1234155
# 14817    1234155
# 14818    1234155
# Name: userid, dtype: int64 14674    2015-10-02 16:06
# 14675    2015-02-02 16:13
# 14817    2015-07-03 17:13
# 14818    2015-03-03 17:23
# Name: timestamp, dtype: object
# 72542    1274975
# 73086    1274975
# Name: userid, dtype: int64 72542    2015-09-12 11:48
# 73086    2015-03-14 04:23
# Name: timestamp, dtype: object
# 79706    1277697
# 79727    1277697
# 79977    1277697
# 80265    1277697
# 80553    1277697
# Name: userid, dtype: int64 79706    2015-08-01 06:01
# 79727    2015-04-01 07:03
# 79977    2015-07-01 16:43
# 80265    2015-09-02 13:13
# 80553    2015-06-03 05:17
# Name: timestamp, dtype: object
# 49010    1279226
# 49242    1279226
# 49504    1279226
# Name: userid, dtype: int64 49010    2015-10-31 11:19
# 49242    2015-06-01 11:05
# 49504    2015-11-02 15:12
# Name: timestamp, dtype: object
# 30286    1281434
# Name: userid, dtype: int64 30286    2015-01-06 17:05
# Name: timestamp, dtype: object
# 65506    1289045
# Name: userid, dtype: int64 65506    2015-03-11 09:10
# Name: timestamp, dtype: object
# 80127    1299163
# 80959    1299163
# Name: userid, dtype: int64 80127    2015-12-02 07:15
# 80959    2015-10-04 03:28
# Name: timestamp, dtype: object
# 75585    1305033
# 75819    1305033
# 76093    1305033
# Name: userid, dtype: int64 75585    2015-08-21 18:58
# 75819    2015-04-22 14:44
# 76093    2015-06-23 13:59
# Name: timestamp, dtype: object
# 10071    1306931
# Name: userid, dtype: int64 10071    2015-02-22 08:57
# Name: timestamp, dtype: object
# 66701    1322901
# Name: userid, dtype: int64 66701    2015-12-16 18:35
# Name: timestamp, dtype: object
# 49405    1332303
# Name: userid, dtype: int64 49405    2015-03-02 08:37
# Name: timestamp, dtype: object
# 13663    1333487
# Name: userid, dtype: int64 13663    2015-05-22 17:26
# Name: timestamp, dtype: object
# 37128    1336328
# 37355    1336328
# 37417    1336328
# Name: userid, dtype: int64 37128    2015-04-08 09:33
# 37355    2015-07-09 08:22
# 37417    2015-07-09 14:06
# Name: timestamp, dtype: object
# 9286     1341773
# 13031    1341773
# 17137    1341773
# Name: timestamp, dtype: object
# 46820    1461057
# 46821    1461057
# Name: userid, dtype: int64 46820    2015-03-22 04:37
# 46821    2015-05-22 04:38
# Name: timestamp, dtype: object
# 19821    1474773
# 29577    1474773
# Name: userid, dtype: int64 19821    2015-09-09 09:13
# 29577    2015-10-02 07:13
# Name: timestamp, dtype: object
# 63995    1475417
# Name: userid, dtype: int64 63995    2015-01-04 13:10
# Name: timestamp, dtype: object
# 40533    1480102
# Name: userid, dtype: int64 40533    2015-06-25 12:10
# Name: timestamp, dtype: object
# 65038    1490541
# 65096    1490541
# 65205    1490541
# 65420    1490541
# 65421    1490541
# Name: userid, dtype: int64 65038    2015-09-09 06:59
# 65096    2015-10-09 09:36
# 65205    2015-07-09 15:33
# 65420    2015-05-10 15:32
# 65421    2015-11-10 15:33
# Name: timestamp, dtype: object
# 78072    1509655
# Name: userid, dtype: int64 78072    2015-05-28 03:33
# Name: timestamp, dtype: object
# 45192    1526575
# Name: userid, dtype: int64 45192    2015-02-15 15:56
# Name: timestamp, dtype: object
# 58394    1535476
# Name: userid, dtype: int64 58394    2015-03-10 02:47
# Name: timestamp, dtype: object
# 59894    1546150
# 59955    1546150
# 60211    1546150
# 60393    1546150
# 61024    1546150
# Name: userid, dtype: int64 59894    2015-06-15 17:36
# 59955    2015-02-16 08:30
# 60211    2015-01-17 15:05
# 60393    2015-12-18 09:21
# 61024    2015-08-20 16:39
# Name: timestamp, dtype: object
# 65014    1553898
# Name: userid, dtype: int64 65014    2015-05-09 05:45
# Name: timestamp, dtype: object
# 72406    1554032
# Name: userid, dtype: int64 72406    2015-09-11 18:25
# Name: timestamp, dtype: object
# 48573    1555927
# 48576    1555927
# 48693    1555927
# 49091    1555927
# Name: userid, dtype: int64 48573    2015-05-29 15:26
# 48576    2015-08-29 15:50
# 48693    2015-02-30 06:32
# 49091    2015-03-31 16:20
# Name: timestamp, dtype: object
# 33365    1558354
# 33490    1558354
# 33602    1558354
# 33802    1558354
# 33958    1558354
# 34387    1558354
# 34502    1558354
# 47700    1558354
# 47707    1558354
# 47715    1558354
# Name: userid, dtype: int64 33365    2015-11-21 19:01
# 33490    2015-08-22 12:26
# 33602    2015-04-23 05:54
# 33802    2015-03-24 05:51
# 33958    2015-09-24 17:45
# 34387    2015-08-27 04:10
# 34502    2015-06-27 15:03
# 47700    2015-02-25 17:47
# 47707    2015-09-25 18:05
# 47715    2015-10-25 18:51
# Name: timestamp, dtype: object
# 76399    1567540
# 77744    1567540
# Name: userid, dtype: int64 76399    2015-06-24 10:21
# 77744    2015-10-27 09:06
# Name: timestamp, dtype: object
# 21313    1581218
# Name: userid, dtype: int64 21313    2015-11-18 13:56
# Name: timestamp, dtype: object
# 21458    1583237
# 21460    1583237
# Name: userid, dtype: int64 21458    2015-10-19 06:29
# 21460    2015-06-19 06:31
# Name: timestamp, dtype: object
# 17688    1584440
# Name: userid, dtype: int64 17688    2015-06-26 06:32
# Name: timestamp, dtype: object
# 38158    1607389
# 38789    1607389
# 39443    1607389
# 40323    1607389
# 40703    1607389
# Name: userid, dtype: int64 38158    2015-09-13 05:32
# 70714    2015-11-05 08:25
# 77978    2015-02-27 17:27
# Name: timestamp, Length: 126, dtype: object
# 19576    49447881
# 19627    49447881
# 19629    49447881
# 19632    49447881
# 19678    49447881
# 19725    49447881
# 19748    49447881
# 19925    49447881
# 19926    49447881
# 19927    49447881
# 19928    49447881
# 19929    49447881
# 19930    49447881
# 19931    49447881
# 19933    49447881
# 19959    49447881
# Name: userid, dtype: int64 19576    2015-12-07 11:00
# 19627    2015-03-07 16:13
# 19629    2015-06-07 16:17
# 19632    2015-10-07 16:55
# 19678    2015-08-08 08:51
# 19725    2015-02-08 14:31
# 19748    2015-06-08 17:04
# 19925    2015-03-10 05:26
# 19926    2015-05-10 05:28
# 19927    2015-11-10 05:29
# 19928    2015-01-10 05:31
# 19929    2015-09-10 05:32
# 19930    2015-05-10 05:35
# 19931    2015-10-10 05:41
# 19933    2015-05-10 05:54
# 19959    2015-03-10 08:35
# Name: timestamp, dtype: object
# 37657    49449344
# Name: userid, dtype: int64 37657    2015-02-10 15:20
# Name: timestamp, dtype: object
# 69131    49452708
# 70058    49452708
# Name: userid, dtype: int64 69131    2015-07-28 12:32
# 70058    2015-07-01 19:01
# Name: timestamp, dtype: object
# 23936    49453169
# 24123    49453169
# 24125    49453169
# 32240    49453169
# Name: userid, dtype: int64 23936    2015-01-01 08:17
# 24123    2015-11-02 02:36
# 24125    2015-06-02 02:40
# 32240    2015-11-16 05:07
# Name: timestamp, dtype: object
# 36190    49463833
# Name: userid, dtype: int64 36190    2015-09-04 10:21
# Name: timestamp, dtype: object
# 19870    49472909
# Name: userid, dtype: int64 19870    2015-04-09 14:50
# Name: timestamp, dtype: object
# 54345    49484497
# Name: userid, dtype: int64 54345    2015-11-24 04:42
# Name: timestamp, dtype: object
# 56449    49487004
# 56728    49487004
# 56737    49487004
# 56910    49487004
# 57084    49487004
# 57102    49487004
# Name: userid, dtype: int64 56449    2015-10-02 13:33
# 56728    2015-07-04 03:11
# 56737    2015-06-04 04:09
# 56910    2015-02-04 14:42
# 57084    2015-04-05 08:25
# 57102    2015-12-05 09:39
# Name: timestamp, dtype: object
# 47137    49496216
# Name: userid, dtype: int64 47137    2015-02-23 12:46
# Name: timestamp, dtype: object
# 31758    49501715
# Name: userid, dtype: int64 31758    2015-12-14 10:55
# Name: timestamp, dtype: object
# 14329    49506718
# 15170    49506718
# 15523    49506718
# 16008    49506718
# 16950    49506718
# 17113    49506718
# 17224    49506718
# 17261    49506718
# 17501    49506718
# 23246    49506718
# 23343    49506718
# 31961    49506718
# 41615    49506718
# 41865    49506718
# 42591    49506718
# 42663    49506718
# 42712    49506718
# 42900    49506718
# 43077    49506718
# 43160    49506718
# 43334    49506718
# 43603    49506718
# 43639    49506718
# 43756    49506718
# 45652    49506718
# 46014    49506718
# 46671    49506718
# 47409    49506718
# 47447    49506718
# 47521    49506718
# 47620    49506718
# 47838    49506718
# 47922    49506718
# 48140    49506718
# 48305    49506718
# 48639    49506718
# 48748    49506718
# 49375    49506718
# 49629    49506718
# 51053    49506718
# 51354    49506718
# 51693    49506718
# 51855    49506718
# 37433    2015-02-09 15:07
# 37647    2015-08-10 14:59
# Name: timestamp, dtype: object
# 1955    49530382
# 1956    49530382
# Name: userid, dtype: int64 1955    2015-06-30 10:10
# 1956    2015-05-30 10:13
# Name: timestamp, dtype: object
# 42623    49533388
# 42625    49533388
# 42634    49533388
# 61318    49533388
# 61556    49533388
# 61557    49533388
# 64619    49533388
# 65075    49533388
# 66027    49533388
# 68536    49533388
# 68697    49533388
# Name: userid, dtype: int64 42623    2015-06-04 15:01
# 42625    2015-07-04 15:03
# 42634    2015-11-04 15:36
# 61318    2015-05-22 12:55
# 61556    2015-11-23 17:56
# 61557    2015-11-23 17:57
# 64619    2015-07-07 15:24
# 65075    2015-05-09 08:31
# 66027    2015-01-14 02:07
# 68536    2015-11-25 17:07
# 68697    2015-07-26 11:24
# Name: timestamp, dtype: object
# 64784    49534498
# 65107    49534498
# Name: userid, dtype: int64 64784    2015-08-08 10:57
# 65107    2015-09-09 10:07
# Name: timestamp, dtype: object
# 79655    49536423
# Name: userid, dtype: int64 79655    2015-10-01 22:01
# Name: timestamp, dtype: object
# 35698    49552585
# 35828    49552585
# Name: userid, dtype: int64 35698    2015-01-02 14:01
# 35828    2015-03-03 02:06
# Name: timestamp, dtype: object
# 38454    49574316
# 38743    49574316
# 38825    49574316
# 38885    49574316
# 39199    49574316
# 39257    49574316
# Name: userid, dtype: int64 38454    2015-05-14 10:13
# 38743    2015-06-15 16:41
# 38825    2015-01-16 07:30
# 38885    2015-11-16 12:49
# 39199    2015-01-18 06:18
# 39257    2015-01-18 09:42
# Name: timestamp, dtype: object
# 77883    49577772
# Name: userid, dtype: int64 77883    2015-03-27 13:54
# Name: timestamp, dtype: object
# 6027    49590511
# Name: userid, dtype: int64 6027    2015-11-29 20:01
# Name: timestamp, dtype: object
# 73973    49602519
# 74067    49602519
# Name: userid, dtype: int64 73973    2015-05-17 04:00
# 74067    2015-04-17 09:10
# Name: timestamp, dtype: object
# 56769    49607110
# Name: userid, dtype: int64 56769    2015-03-04 06:50
# Name: timestamp, dtype: object
# 388      49610767
# 875      49610767
# 889      49610767
# 65448    49610767
# 65496    49610767
# Name: userid, dtype: int64 388      2015-10-11 08:55
# 875      2015-05-16 15:24
# 889      2015-06-16 17:16
# 65448    2015-11-10 18:04
# 65496    2015-03-11 08:08
# Name: timestamp, dtype: object
# 21968    49617513
# 22273    49617513
# 24665    49617513
# 24874    49617513
# 25848    49617513
# 25889    49617513
# 26083    49617513
# 26230    49617513
# 31208    49617513
# 33160    49617513
# 43502    49617513
# 43753    49617513
# 44645    49617513
# 45786    49617513
# 46647    49617513
# 46920    49617513
# 47007    49617513
# 48374    49617513
# 50263    49617513
# 50552    49617513
# 50744    49617513
# 51634    49617513
# 52040    49617513
# 52352    49617513
# 53063    49617513
# 53792    49617513
# 57472    49617513
# 60384    49617513
# 64068    49617513
# Name: userid, dtype: int64 21968    2015-08-21 04:02
# 22273    2015-04-22 14:42
# 24665    2015-05-04 13:00
# 24874    2015-06-05 13:57
# 25848    2015-02-11 04:35
# 25889    2015-01-11 07:06
# 65208    49699443
# Name: userid, dtype: int64 16087    2015-09-14 10:30
# 16097    2015-11-14 11:46
# 16098    2015-11-14 11:47
# 16099    2015-11-14 11:48
# 16103    2015-05-14 12:31
# 16112    2015-09-14 12:50
# 16147    2015-10-14 16:54
# 16148    2015-11-14 17:08
# 16150    2015-10-14 17:13
# 16151    2015-10-14 17:15
# 16152    2015-03-14 17:15
# 16154    2015-05-14 17:17
# 16181    2015-05-15 05:26
# 16183    2015-11-15 05:28
# 16196    2015-05-15 07:28
# 16214    2015-12-15 08:46
# 16216    2015-04-15 08:47
# 16290    2015-12-15 16:22
# 16314    2015-11-16 02:03
# 16326    2015-02-16 03:46
# 16339    2015-01-16 05:12
# 16340    2015-11-16 05:25
# 16341    2015-05-16 05:26
# 16356    2015-09-16 06:29
# 16377    2015-10-16 08:55
# 16417    2015-04-16 13:44
# 16440    2015-10-16 15:55
# 16441    2015-05-16 15:57
# 16443    2015-09-16 16:09
# 43485    2015-02-08 10:34
# 43619    2015-11-09 05:09
# 43679    2015-12-09 09:03
# 43682    2015-05-09 09:05
# 43884    2015-10-10 06:53
# 44148    2015-01-11 07:24
# 44149    2015-05-11 07:27
# 44271    2015-08-11 17:16
# 56843    2015-04-04 11:22
# 57054    2015-06-05 06:41
# 57055    2015-10-05 06:42
# 57081    2015-02-05 08:09
# 57260    2015-07-06 01:16
# 57291    2015-10-06 05:10
# 57383    2015-06-06 11:50
# 57457    2015-03-06 16:28
# 57525    2015-11-07 04:18
# 62778    2015-09-30 07:44
# 64754    2015-08-08 09:15
# 65208    2015-04-09 15:46
# Name: timestamp, dtype: object
# 14524    49703437
# 14734    49703437
# Name: userid, dtype: int64 14524    2015-08-01 15:07
# 14734    2015-02-03 07:22
# Name: timestamp, dtype: object
# 36654    49712314
# 36655    49712314
# 36656    49712314
# 36882    49712314
# 36893    49712314
# Name: userid, dtype: int64 36654    2015-11-06 07:54
# 36655    2015-10-06 07:55
# 36656    2015-11-06 07:55
# 36882    2015-04-07 06:31
# 36893    2015-09-07 07:50
# Name: timestamp, dtype: object
# 46856    49713639
# Name: userid, dtype: int64 46856    2015-10-22 08:18
# Name: timestamp, dtype: object
# 58332    49715828
# Name: userid, dtype: int64 58332    2015-06-09 15:51
# Name: timestamp, dtype: object
# 64816    49721532
# 64821    49721532
# Name: userid, dtype: int64 64816    2015-10-08 12:47
# 64821    2015-09-08 13:02
# Name: timestamp, dtype: object
# 69451    49724729
# 69453    49724729
# Name: userid, dtype: int64
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.9/shutil.py:1373, in get_terminal_size(fallback)
#    1372 try:
# -> 1373     size = os.get_terminal_size(sys.__stdout__.fileno())
#    1374 except (AttributeError, ValueError, OSError):
#    1375     # stdout is None, closed, detached, or not a terminal, or
#    1376     # os.get_terminal_size() is unsupported
#
# OSError: [Errno 25] Inappropriate ioctl for device
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
#       1 for i in grouped:
# ----> 2     print(i[1]["userid"],i[1]["timestamp"])
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/series.py:1503, in Series.__repr__(self)
#    1499 def __repr__(self) -> str:
#    1500     """
#    1501     Return a string representation for a particular Series.
#    1502     """
# -> 1503     repr_params = fmt.get_series_repr_params()
#    1504     return self.to_string(**repr_params)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/io/formats/format.py:533, in get_series_repr_params()
#     516 def get_series_repr_params() -> dict[str, Any]:
#     517     """Get the parameters used to repr(Series) calls using Series.to_string.
#     518
#     519     Supplying these parameters to Series.to_string is equivalent to calling
#    (...)
#     531     True
#     532     """
# --> 533     width, height = get_terminal_size()
#     534     max_rows = (
#     535         height
#     536         if get_option("display.max_rows") == 0
#     537         else get_option("display.max_rows")
#     538     )
#     539     min_rows = (
#     540         height
#     541         if get_option("display.max_rows") == 0
#     542         else get_option("display.min_rows")
#     543     )
#
# File /opt/conda/lib/python3.9/shutil.py:1373, in get_terminal_size(fallback)
#    1371 if columns <= 0 or lines <= 0:
#    1372     try:
# -> 1373         size = os.get_terminal_size(sys.__stdout__.fileno())
#    1374     except (AttributeError, ValueError, OSError):
#    1375         # stdout is None, closed, detached, or not a terminal, or
#    1376         # os.get_terminal_size() is unsupported
#    1377         size = os.terminal_size(fallback)
#
# KeyboardInterrupt:

# %%
for i in grouped:
    print(i)
    break
# Out:
# (16301,              lat        lon         timestamp  userid  \
# 30512 -24.760170  31.339430  2015-06-08 04:34   16301
# 30535 -24.759508  31.371200  2015-02-08 06:18   16301
# 30545 -24.774158  31.380342  2015-09-08 06:58   16301
# 30770 -24.749845  31.338317  2015-02-09 08:09   16301
# 38232 -24.791483  31.865172  2015-05-13 10:51   16301
# 38235 -24.995803  31.592000  2015-03-13 10:59   16301
# 38909 -25.102336  31.894695  2015-08-16 14:27   16301
# 38911 -24.985142  31.625662  2015-09-16 14:30   16301
# 38913 -25.122811  31.911867  2015-11-16 14:31   16301
#
#                                 geometry
# 30512  POINT (-4684246.015 14939886.378)
# 30535  POINT (-4681550.088 14943799.279)
# 30545  POINT (-4682360.424 14945977.388)
# 30770  POINT (-4683233.102 14939015.568)
# 38232  POINT (-4643987.777 15007357.316)
# 38235  POINT (-4688386.821 14988087.394)
# 38909  POINT (-4674277.458 15033193.770)
# 38911  POINT (-4684442.069 14991502.196)
# 38913  POINT (-4674988.223 15036783.842)  )

# %%
# REPLACE THE ERROR BELOW WITH YOUR OWN CODE
raise NotImplementedError()

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

assert movements.crs.to_epsg() == 32735
assert len(movements) == len(data.userid.unique())
#Check the result
print(type(movements))
print(movements.crs)
print(movements['geometry'].head())

# %% [markdown]
# 5. **Finally, calculate the lenghts of the lines into a new column called `distance` in the `movements` GeoDataFrame.**

# %%
# REPLACE THE ERROR BELOW WITH YOUR OWN CODE
raise NotImplementedError()

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

# Check the output - the summed distance should be around 96700
print(f"The visitors in total travelled {movements.dist.sum() / 10000:.0f} km")

# %% [markdown]
# **You should now be able to answer the following questions:**
#
# - *What was the shortest distance travelled?*
# - *What was the mean distance travelled?*
# - *What was the maximum distance travelled?*

# %%
# REPLACE THE ERROR BELOW WITH YOUR OWN CODE
raise NotImplementedError()

# %% [markdown]
# **Last step is to save the data of into a geopackage called `some_movements.gpkg`**

# %%
# REPLACE THE ERROR BELOW WITH YOUR OWN CODE
raise NotImplementedError()

# %%
# NON-EDIT CODE CELL FOR TESTING YOUR SOLUTION

import os

#Check if output file exists
assert os.path.isfile(fp), "Output file does not exits."
